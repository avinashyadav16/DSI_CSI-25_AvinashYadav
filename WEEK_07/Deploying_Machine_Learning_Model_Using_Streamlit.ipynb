# %% [markdown]
# # **Deploying Machine Learning Models with Streamlit**

# %% [markdown]
# ## **TASK**
#
# - Develop a web application using Streamlit to deploy a trained machine learning model.
# - The app should allow users to input data, receive predictions, and understand model outputs through visualizations.
#
# ## **RESOURCES**
#
# - https://docs.streamlit.io/https://machinelearningmastery.com/how-to-quickly-deploy-machine-learning-models-streamlit/

# %% [markdown]
# ## **Project Overview**
#
# This project demonstrates how to deploy a trained machine learning model using Streamlit, creating an interactive web application for house price prediction. The application allows users to input house characteristics and receive price predictions with visualizations.
#
# ### **Key Features:**
#
# 1. **Interactive User Interface**: Easy-to-use sidebar for inputting house features
# 2. **Predictions**: Instant price predictions based on user inputs
# 3. **Data Visualizations**: Charts showing feature importance, price distributions

# %%
import streamlit as st
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

print("✅ All packages imported successfully!")
# Out:
# ✅ All packages imported successfully!

# %% [markdown]
# ### **2. Requirements File**
#
# Create the `requirements.txt` file with all necessary dependencies:

# %%
# Display the contents of requirements.txt
with open('requirements.txt', 'r') as f:
    requirements = f.read()

print("📋 Requirements.txt contents:")
print(requirements)
# Out:
# 📋 Requirements.txt contents:
# streamlit==1.28.1
# pandas==2.0.3
# numpy==1.24.3
# scikit-learn==1.3.0
# matplotlib==3.7.2
# seaborn==0.12.2
# plotly==5.15.0
# scipy==1.11.1

# %% [markdown]
# ### **3. Streamlit Application Structure**
#
# The `app.py` file contains our complete Streamlit application with the following components:
#
# #### **Key Features:**
#
# 1. **Data Loading and Preprocessing**
#
#    - Automatic loading of the training dataset
#    - Missing value handling with domain-specific strategies
#    - Feature engineering (house age, total area, bathroom count, etc.)
#    - Categorical encoding (ordinal and one-hot encoding)
#
# 2. **Model Training**
#
#    - Multiple model comparison capability
#    - Feature selection using statistical tests
#    - Robust scaling for numerical features
#    - Cross-validation for model evaluation
#
# 3. **User Interface**
#
#    - **Sidebar**: Interactive input widgets for house features
#    - **Main Area**: Data overview, visualizations, and predictions
#    - **Tabs**: Advanced analytics with multiple visualization types
#
# 4. **Prediction System**
#
#    - Real-time price prediction based on user inputs
#    - Price range estimation with confidence intervals
#    - Market comparison against average/median prices
#
# 5. **Visualizations**
#    - Feature importance charts

# %% [markdown]
# ### **4. Running the Application**
#
# #### **Local Deployment Steps:**
#
# 1. **Install Dependencies:**
#
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 2. **Run the Streamlit App:**
#
#    ```bash
#    streamlit run app.py
#    ```
#
# 3. **Access the Application:**
#    - The app will automatically open in the default web browser
#    - Default URL: `http://localhost:8501`
#
# #### **Application Usage:**
#
# 1. **Input House Features:**
#
#    - Use the sidebar to input various house characteristics
#    - Adjust sliders and select options for different features
#    - Key inputs include: Living Area, Lot Area, Overall Quality, Year Built, etc.
#
# 2. **Get Predictions:**
#
#    - Click the "Predict Price" button
#    - View the predicted price with confidence intervals
#
# 3. **Explore Analytics:**
#    - View feature importance charts

# %% [markdown]
# ### **5. Advanced Deployment Options**
#
# #### **Cloud Deployment Platforms:**
#
# 1. **Streamlit Community Cloud (Recommended)**
#
#    - Free hosting for public repositories
#    - Easy deployment directly from GitHub
#    - Automatic updates when you push to GitHub
#    - Steps:
#      - Pushing code to GitHub repository
#      - Visit [share.streamlit.io](https://share.streamlit.io)
#      - Connect GitHub account
#      - Select repository and deploy
#
# #### **Production Considerations:**
#
# - **Performance**: Optimize model loading with caching
# - **Security**: Implement input validation and sanitization
# - **Monitoring**: Add logging and error tracking
# - **Scalability**: Consider load balancing for high traffic
# - **Data**: Secure data storage and backup strategies

# %% [markdown]
# ## **Project Results and Conclusion**
#
# ### **✅ Completed Deliverables:**
#
# 1. **📱 Interactive Web Application**:
#
#    - Full-featured Streamlit app (`app.py`)
#    - Comprehensive data visualizations
#
# 2. **🛠️ Complete Deployment Package**:
#
#    - `requirements.txt` with all dependencies
#    - Error handling and user validation
#
# 3. **📊 Advanced Analytics Features**:
#
#    - Feature importance analysis
#
# 4. **🎯 User-Friendly Interface**:
#    - Intuitive sidebar for input parameters
#    - Professional styling with custom CSS
#    - Responsive design for different screen sizes
#    - Clear visualizations and explanations

# %% [markdown]
# ## **🚀 Quick Start Guide**
#
# ### **To run the application:**
#
# 1. **Open Terminal/Command Prompt** in this directory
#
# 2. **Install dependencies:**
#
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 3. **Run the Streamlit app:**
#
#    ```bash
#    streamlit run app.py
#    ```
#
# 4. **Access the application:**
#
#    - Your web browser will automatically open
#    - If not, navigate to: `http://localhost:8501`
#
# 5. **Use the application:**
#    - Adjust house features in the sidebar
#    - Click "Predict Price" to get estimates
#    - Explore different tabs for analytics
#    - Try different feature combinations
